# %% [markdown]
# <a href="https://colab.research.google.com/github/xusanxondev/python-darslar-javob/blob/main/birnchi_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # Heading
#   -kirish
#   -muqaddima

# %%
for i in range(3):
  print(i)
# Out:
# 0
# 1
# 2

# %%
import numpy as np

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import pandas as pd

files= pd.read_excel('./data/DEKABR(27) golden life 27kun.xlsx')

files.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN  Маркет : голден лайф.                         ...
# 3         NaN                                                  №
# 4         NaN                                                  1
#
#       Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0            NaN        NaN        NaN        NaN        NaN        NaN
# 1            NaN        NaN        NaN        NaN        NaN        NaN
# 2            NaN        NaN        NaN        NaN        NaN        NaN
# 3          Пекар          %    П/Пекар          %    П/Пекар          %
# 4  сох.сухроббек        0.6  раж.еркин        0.4        NaN        NaN
#
#   Unnamed: 8     Unnamed: 9 Unnamed: 10       Unnamed: 11 Unnamed: 12  \
# ...
